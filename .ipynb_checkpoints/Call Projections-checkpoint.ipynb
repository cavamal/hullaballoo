# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
from pandas.plotting import scatter_matrix

# %matplotlib inline

df_calls = pd.read_csv('data/dataset.csv')
df_pop = pd.read_csv('data/populationforecast.csv')

# %%
df_calls.head()
# Out:
#    Neighbourhood  Year  PopulationAge_0_to_14  PopulationAge_15_to_24  \
# 0              1  2001                   3579                    1715
# 1              1  2002                   3790                    1813
# 2              1  2003                   3819                    2018
# 3              1  2004                   4074                    2154
# 4              1  2005                   3496                    2195
#
#    PopulationAge_25_to_34  PopulationAge_35_to_44  PopulationAge_45_to_54  \
# 0                    1065                     640                     374
# 1                    1167                     669                     434
# 2                    1321                     759                     455
# 3                    1359                     967                     469
# 4                    1416                     855                     493
#
#    PopulationAge_55_to_70  PopulationAge_71_to_120  Total_Population  Calls
# 0                     276                      138              7787    882
# 1                     303                      153              8329    962
# 2                     356                      142              8870    938
# 3                     380                      173              9576   1056
# 4                     439                      155              9049   1006

# %% [markdown]
# The data is separated in to 4 neighbourhoods - 1 thru 4. There are two residential, one residential/commercial, and one industrial. I need to figure out what the projected demand in each neighbourhood is to figure out what they're expected calls are.
#
# Neighbourhood 4 has no population data, as nobody lives there full-time.
#
# I see us needing to solve the following problems:
#
# 1. Come up with call rates for each neighbourhood.
#
# 2. Correlate call-rates with population groups.
#
# 3. Estimate population for industrial neighbourhood based on calls.
#
# 4. Estimate call rate based on projected populations.
#
# Do I need to look at accuracy of population predictions? Get data from some third party?

# %%
df_calls.dtypes
# Out:
# Neighbourhood              int64
# Year                       int64
# PopulationAge_0_to_14      int64
# PopulationAge_15_to_24     int64
# PopulationAge_25_to_34     int64
# PopulationAge_35_to_44     int64
# PopulationAge_45_to_54     int64
# PopulationAge_55_to_70     int64
# PopulationAge_71_to_120    int64
# Total_Population           int64
# Calls                      int64
# dtype: object

# %%
df_calls[df_calls['Neighbourhood']==1]
# Out:
#     Neighbourhood  Year  PopulationAge_0_to_14  PopulationAge_15_to_24  \
# 0               1  2001                   3579                    1715
# 1               1  2002                   3790                    1813
# 2               1  2003                   3819                    2018
# 3               1  2004                   4074                    2154
# 4               1  2005                   3496                    2195
# 5               1  2006                   3678                    2246
# 6               1  2007                   3693                    2385
# 7               1  2008                   3541                    2627
# 8               1  2009                   3685                    2489
# 9               1  2010                   3607                    2900
# 10              1  2011                   3670                    2931
# 11              1  2012                   3341                    3065
# 12              1  2013                   3404                    3060
# 13              1  2014                   3521                    3498
# 14              1  2015                   3337                    3259
# 15              1  2016                   3600                    3548
# 16              1  2017                   3485                    3236
# 17              1  2018                   3460                    3018
#
#     PopulationAge_25_to_34  PopulationAge_35_to_44  PopulationAge_45_to_54  \
# 0                     1065                     640                     374
# 1                     1167                     669                     434
# 2                     1321                     759                     455
# 3                     1359                     967                     469
# 4                     1416                     855                     493
# 5                     1401                     922                     531
# 6                     1692                    1094                     619
# 7                     1996                    1082                     581
# 8                     2013                    1199                     626
# 9                     2048                    1244                     729
# 10                    2361                    1430                     837
# 11                    2323                    1596                     865
# 12                    2440                    1638                     893
# 13                    2789                    1860                    1079
# 14                    2822                    1748                    1114
# 15                    2987                    1959                    1083
# 16                    3214                    1854                    1207
# 17                    3123                    2032                    1251
#
#     PopulationAge_55_to_70  PopulationAge_71_to_120  Total_Population  Calls
# 0                      276                      138              7787    882
# 1                      303                      153              8329    962
# 2                      356                      142              8870    938
# 3                      380                      173              9576   1056
# 4                      439                      155              9049   1006
# 5                      420                      161              9359   1005
# 6                      485                      184             10152   1194
# 7                      507                      188             10522    933
# 8                      525                      209             10746   1213
# 9                      573                      213             11314   1318
# 10                     616                      239             12084   1389
# 11                     672                      231             12093   1611
# 12                     763                      266             12464   1453
# 13                     786                      266             13799   1593
# 14                     854                      293             13427   1520
# 15                     949                      355             14481   1828
# 16                     968                      351             14315   1705
# 17                    1007                      364             14255   1855

# %%
df_calls.shape
# Out:
# (72, 11)

# %%
scatter_matrix(df_calls[df_calls['Neighbourhood']==1],figsize=(15,15));
# Out:
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3152: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=1.0, right=1.0
#   'left=%s, right=%s') % (left, right))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3471: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=1.0, top=1.0
#   'bottom=%s, top=%s') % (bottom, top))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\pandas\plotting\_misc.py:123: RuntimeWarning: invalid value encountered in true_divide
#   adj = (locs - lim1[0]) / (lim1[1] - lim1[0])

# %%
df_calls[df_calls['Neighbourhood']==1].describe()
# Out:
#        Neighbourhood         Year  PopulationAge_0_to_14  \
# count           18.0    18.000000              18.000000
# mean             1.0  2009.500000            3598.888889
# std              0.0     5.338539             182.158912
# min              1.0  2001.000000            3337.000000
# 25%              1.0  2005.250000            3487.750000
# 50%              1.0  2009.500000            3589.500000
# 75%              1.0  2013.750000            3683.250000
# max              1.0  2018.000000            4074.000000
#
#        PopulationAge_15_to_24  PopulationAge_25_to_34  PopulationAge_35_to_44  \
# count               18.000000               18.000000               18.000000
# mean              2675.388889             2085.388889             1308.222222
# std                570.476698              708.833021              465.921295
# min               1715.000000             1065.000000              640.000000
# 25%               2207.750000             1404.750000              933.250000
# 50%               2763.500000             2030.500000             1221.500000
# 75%               3063.750000             2701.750000             1720.500000
# max               3548.000000             3214.000000             2032.000000
#
#        PopulationAge_45_to_54  PopulationAge_55_to_70  \
# count               18.000000               18.000000
# mean               757.777778              604.388889
# std                290.475990              235.311843
# min                374.000000              276.000000
# 25%                502.500000              424.750000
# 50%                677.500000              549.000000
# 75%               1032.500000              780.250000
# max               1251.000000             1007.000000
#
#        PopulationAge_71_to_120  Total_Population        Calls
# count                18.000000         18.000000    18.000000
# mean                226.722222      11256.777778  1303.388889
# std                  74.775590       2201.400398   327.176358
# min                 138.000000       7787.000000   882.000000
# 25%                 164.000000       9413.250000  1005.250000
# 50%                 211.000000      11030.000000  1265.500000
# 75%                 266.000000      13186.250000  1574.750000
# max                 364.000000      14481.000000  1855.000000

# %%
#check neighbourhood 1 for relationship between calls and pop 
filt1 = df_calls['Neighbourhood']==1

plt.scatter(df_calls[filt1]['Total_Population'],df_calls[filt1]['Calls']);

# %%
#check neighbourhood 2 for relationship between calls and pop
filt1 = df_calls['Neighbourhood']==2
df_calls['Total_Population']

plt.scatter(df_calls[filt1]['Total_Population'],df_calls[filt1]['Calls']);

# %%
#check neighbourhood 3 for relationship between calls and pop

filt1 = df_calls['Neighbourhood']==3

plt.scatter(df_calls[filt1]['Total_Population'],df_calls[filt1]['Calls']);

# %%
plt.scatter()

# %%
# Get the combined population to test against the neighbourhood 2. 
total_pop = []

for x in range(2001,2019):
    total_pop.append(df_calls[df_calls['Year']==x]['Total_Population'].sum())

total_pop
# Out:
# [17856,
#  21163,
#  23095,
#  22397,
#  21042,
#  22336,
#  24922,
#  25192,
#  26211,
#  28160,
#  27489,
#  28228,
#  27418,
#  32361,
#  31520,
#  34035,
#  33665,
#  33896]

# %%
filt1 = df_calls['Neighbourhood']==2

plt.scatter(total_pop,df_calls[filt1]['Calls']);

# %%
len(df_calls[filt1]['Calls'])
# Out:
# 18

# %%
len(total_pop)
# Out:
# 17

# %%
filt1 = df_calls['Neighbourhood']==4

plt.scatter(total_pop,df_calls[filt1]['Calls']);

# %%
filt1 = df_calls['Neighbourhood']==2

# %%
scatter_matrix(df_calls[filt1],figsize=(15,15));
# Out:
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3152: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=2.0, right=2.0
#   'left=%s, right=%s') % (left, right))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3471: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=2.0, top=2.0
#   'bottom=%s, top=%s') % (bottom, top))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3471: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=2.0, top=2.0
#   'bottom=%s, top=%s') % (bottom, top))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3471: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=2.0, top=2.0
#   'bottom=%s, top=%s') % (bottom, top))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3471: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=2.0, top=2.0
#   'bottom=%s, top=%s') % (bottom, top))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3471: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=2.0, top=2.0
#   'bottom=%s, top=%s') % (bottom, top))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3471: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=2.0, top=2.0
#   'bottom=%s, top=%s') % (bottom, top))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3471: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=2.0, top=2.0
#   'bottom=%s, top=%s') % (bottom, top))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3471: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=2.0, top=2.0
#   'bottom=%s, top=%s') % (bottom, top))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3471: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=2.0, top=2.0
#   'bottom=%s, top=%s') % (bottom, top))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3471: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=2.0, top=2.0
#   'bottom=%s, top=%s') % (bottom, top))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3152: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=2.0, right=2.0
#   'left=%s, right=%s') % (left, right))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3152: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=2.0, right=2.0
#   'left=%s, right=%s') % (left, right))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3152: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=2.0, right=2.0
#   'left=%s, right=%s') % (left, right))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3152: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=2.0, right=2.0
#   'left=%s, right=%s') % (left, right))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3152: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=2.0, right=2.0
#   'left=%s, right=%s') % (left, right))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3152: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=2.0, right=2.0
#   'left=%s, right=%s') % (left, right))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3152: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=2.0, right=2.0
#   'left=%s, right=%s') % (left, right))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3152: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=2.0, right=2.0
#   'left=%s, right=%s') % (left, right))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3152: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=2.0, right=2.0
#   'left=%s, right=%s') % (left, right))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\matplotlib\axes\_base.py:3152: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=2.0, right=2.0
#   'left=%s, right=%s') % (left, right))
# C:\Users\Maliarenko\Anaconda3\envs\dataInvestigation\lib\site-packages\pandas\plotting\_misc.py:123: RuntimeWarning: invalid value encountered in true_divide
#   adj = (locs - lim1[0]) / (lim1[1] - lim1[0])

# %% [markdown]
# ### Estimating Living Population
